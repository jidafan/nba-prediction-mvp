# %%
import pandas as pd

# %%
mvps = pd.read_csv("mvps.csv")

# %%
mvps
# Out:
#      Unnamed: 0 Rank           Player  Age   Tm  First  Pts Won  Pts Max  \
# 0             0    1    Magic Johnson   30  LAL   27.0    636.0      920
# 1             1    2  Charles Barkley   26  PHI   38.0    614.0      920
# 2             2    3   Michael Jordan   26  CHI   21.0    564.0      920
# 3             3    4      Karl Malone   26  UTA    2.0    214.0      920
# 4             4    5    Patrick Ewing   27  NYK    1.0    162.0      920
# ..          ...  ...              ...  ...  ...    ...      ...      ...
# 508           8    9    Stephen Curry   34  GSW    0.0      5.0     1000
# 509           9   10     Jimmy Butler   33  MIA    0.0      3.0     1000
# 510          10   11     De'Aaron Fox   25  SAC    0.0      2.0     1000
# 511          11  12T    Jalen Brunson   26  NYK    0.0      1.0     1000
# 512          12  12T        Ja Morant   23  MEM    0.0      1.0     1000
#
#      Share   G  ...   TRB   AST  STL  BLK    FG%    3P%    FT%    WS  WS/48  \
# 0    0.691  79  ...   6.6  11.5  1.7  0.4  0.480  0.384  0.890  16.5  0.270
# 1    0.667  79  ...  11.5   3.9  1.9  0.6  0.600  0.217  0.749  17.3  0.269
# 2    0.613  82  ...   6.9   6.3  2.8  0.7  0.526  0.376  0.848  19.0  0.285
# 3    0.233  82  ...  11.1   2.8  1.5  0.6  0.562  0.372  0.762  15.9  0.245
# 4    0.176  82  ...  10.9   2.2  1.0  4.0  0.551  0.250  0.775  13.5  0.205
# ..     ...  ..  ...   ...   ...  ...  ...    ...    ...    ...   ...    ...
# 508  0.005  56  ...   6.1   6.3  0.9  0.4  0.493  0.427  0.915   7.8  0.192
# 509  0.003  64  ...   5.9   5.3  1.8  0.3  0.539  0.350  0.850  12.3  0.277
# 510  0.002  73  ...   4.2   6.1  1.1  0.3  0.512  0.324  0.780   7.4  0.146
# 511  0.001  68  ...   3.5   6.2  0.9  0.2  0.491  0.416  0.829   8.7  0.175
# 512  0.001  61  ...   5.9   8.1  1.1  0.3  0.466  0.307  0.748   6.0  0.148
#
#      Year
# 0    1990
# 1    1990
# 2    1990
# 3    1990
# 4    1990
# ..    ...
# 508  2023
# 509  2023
# 510  2023
# 511  2023
# 512  2023
#
# [513 rows x 22 columns]

# %%
mvps = mvps[["Player", "Year", "Pts Won", "Pts Max", "Share"]]

# %%
mvps
# Out:
#               Player  Year  Pts Won  Pts Max  Share
# 0      Magic Johnson  1990    636.0      920  0.691
# 1    Charles Barkley  1990    614.0      920  0.667
# 2     Michael Jordan  1990    564.0      920  0.613
# 3        Karl Malone  1990    214.0      920  0.233
# 4      Patrick Ewing  1990    162.0      920  0.176
# ..               ...   ...      ...      ...    ...
# 508    Stephen Curry  2023      5.0     1000  0.005
# 509     Jimmy Butler  2023      3.0     1000  0.003
# 510     De'Aaron Fox  2023      2.0     1000  0.002
# 511    Jalen Brunson  2023      1.0     1000  0.001
# 512        Ja Morant  2023      1.0     1000  0.001
#
# [513 rows x 5 columns]

# %%
players = pd.read_csv("players.csv")

# %%
players
# Out:
#        Unnamed: 0   Rk          Player Pos Age   Tm   G  GS    MP   FG  ...  \
# 0               0    1      Mark Acres   C  27  ORL  80  50  21.1  1.7  ...
# 1               1    2   Michael Adams  PG  27  DEN  79  74  34.1  5.0  ...
# 2               2    3    Mark Aguirre  SF  30  DET  78  40  25.7  5.6  ...
# 3               3    4     Danny Ainge  PG  30  SAC  75  68  36.4  6.7  ...
# 4               4    5     Mark Alarie  PF  26  WSB  82  10  23.1  4.5  ...
# ...           ...  ...             ...  ..  ..  ...  ..  ..   ...  ...  ...
# 20061         699  535  Thaddeus Young  PF  34  TOR  54   9  14.7  2.0  ...
# 20062         700  536      Trae Young  PG  24  ATL  73  73  34.8  8.2  ...
# 20063         701  537  Omer Yurtseven   C  24  MIA   9   0   9.2  1.8  ...
# 20064         702  538     Cody Zeller   C  30  MIA  15   2  14.5  2.5  ...
# 20065         703  539     Ivica Zubac   C  25  LAC  76  76  28.6  4.3  ...
#
#        ORB  DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Year
# 0      1.9  3.5  5.4   0.8  0.5  0.3  0.9  3.1   4.5  1990
# 1      0.6  2.2  2.8   6.3  1.5  0.0  1.8  1.7  15.5  1990
# 2      1.5  2.4  3.9   1.9  0.4  0.2  1.6  2.6  14.1  1990
# 3      0.9  3.4  4.3   6.0  1.5  0.2  2.5  3.2  17.9  1990
# 4      1.8  2.7  4.6   1.7  0.7  0.5  1.2  2.7  10.5  1990
# ...    ...  ...  ...   ...  ...  ...  ...  ...   ...   ...
# 20061  1.3  1.8  3.1   1.4  1.0  0.1  0.8  1.6   4.4  2023
# 20062  0.8  2.2  3.0  10.2  1.1  0.1  4.1  1.4  26.2  2023
# 20063  0.9  1.7  2.6   0.2  0.2  0.2  0.4  1.8   4.4  2023
# 20064  1.7  2.6  4.3   0.7  0.2  0.3  0.9  2.2   6.5  2023
# 20065  3.1  6.8  9.9   1.0  0.4  1.3  1.5  2.9  10.8  2023
#
# [20066 rows x 32 columns]

# %%
del players["Unnamed: 0"]
del players["Rk"]

# %%
players
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  \
# 0          Mark Acres   C  27  ORL  80  50  21.1  1.7   3.6  .484  ...  1.9
# 1       Michael Adams  PG  27  DEN  79  74  34.1  5.0  12.5  .402  ...  0.6
# 2        Mark Aguirre  SF  30  DET  78  40  25.7  5.6  11.5  .488  ...  1.5
# 3         Danny Ainge  PG  30  SAC  75  68  36.4  6.7  15.4  .438  ...  0.9
# 4         Mark Alarie  PF  26  WSB  82  10  23.1  4.5   9.6  .473  ...  1.8
# ...               ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...  ...
# 20061  Thaddeus Young  PF  34  TOR  54   9  14.7  2.0   3.7  .545  ...  1.3
# 20062      Trae Young  PG  24  ATL  73  73  34.8  8.2  19.0  .429  ...  0.8
# 20063  Omer Yurtseven   C  24  MIA   9   0   9.2  1.8   3.0  .593  ...  0.9
# 20064     Cody Zeller   C  30  MIA  15   2  14.5  2.5   3.9  .627  ...  1.7
# 20065     Ivica Zubac   C  25  LAC  76  76  28.6  4.3   6.8  .634  ...  3.1
#
#        DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Year
# 0      3.5  5.4   0.8  0.5  0.3  0.9  3.1   4.5  1990
# 1      2.2  2.8   6.3  1.5  0.0  1.8  1.7  15.5  1990
# 2      2.4  3.9   1.9  0.4  0.2  1.6  2.6  14.1  1990
# 3      3.4  4.3   6.0  1.5  0.2  2.5  3.2  17.9  1990
# 4      2.7  4.6   1.7  0.7  0.5  1.2  2.7  10.5  1990
# ...    ...  ...   ...  ...  ...  ...  ...   ...   ...
# 20061  1.8  3.1   1.4  1.0  0.1  0.8  1.6   4.4  2023
# 20062  2.2  3.0  10.2  1.1  0.1  4.1  1.4  26.2  2023
# 20063  1.7  2.6   0.2  0.2  0.2  0.4  1.8   4.4  2023
# 20064  2.6  4.3   0.7  0.2  0.3  0.9  2.2   6.5  2023
# 20065  6.8  9.9   1.0  0.4  1.3  1.5  2.9  10.8  2023
#
# [20066 rows x 30 columns]

# %%
players["Player"] = players["Player"].str.replace("*","", regex = False)

# %%
players.groupby(["Player","Year"]).get_group(("Greg Anderson", 1991))
# Out:
#             Player Pos Age   Tm   G GS    MP   FG  FGA    FG%  ...  ORB  DRB  \
# 485  Greg Anderson  PF  26  TOT  68  2  13.6  1.7  4.0   .430  ...  1.4  3.3
# 486  Greg Anderson  PF  26  MIL  26  0   9.5  1.0  2.8   .370  ...  1.0  1.9
# 487  Greg Anderson  PF  26  NJN   1  0  18.0  4.0  4.0  1.000  ...  4.0  2.0
# 488  Greg Anderson  PF  26  DEN  41  2  16.1  2.1  4.7   .440  ...  1.6  4.1
#
#      TRB  AST  STL  BLK  TOV   PF  PTS  Year
# 485  4.7  0.2  0.5  0.7  1.2  2.1  4.3  1991
# 486  2.9  0.1  0.3  0.3  0.8  1.1  2.7  1991
# 487  6.0  1.0  2.0  0.0  1.0  4.0  8.0  1991
# 488  5.8  0.3  0.6  0.9  1.5  2.6  5.2  1991
#
# [4 rows x 30 columns]

# %%
def single_row(df):
    if df.shape[0] == 1:
        return df
    else:
        row = df[df["Tm"] == "TOT"]
        row["Tm"] = df.iloc[-1,:]["Tm"]
        return row

players = players.groupby(["Player","Year"]).apply(single_row)

# %%
players.head(20)
# Out:
#                                  Player Pos Age   Tm   G  GS    MP   FG   FGA  \
# Player        Year
# A.C. Green    1990 146       A.C. Green  PF  26  LAL  82  82  33.0  4.7   9.8
#               1991 641       A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6
#               1992 1110      A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8
#               1993 1569      A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6
#               1994 2056      A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3
#               1995 2544      A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5
#               1996 3040      A.C. Green  SF  32  PHO  82  36  25.8  2.6   5.4
#               1997 3615      A.C. Green  PF  33  DAL  83  73  30.0  2.8   5.8
#               1998 4202      A.C. Green  PF  34  DAL  82  68  32.3  3.0   6.5
#               1999 4760      A.C. Green  PF  35  DAL  50  35  18.5  2.2   5.1
#               2000 5288      A.C. Green  PF  36  LAL  82  82  23.5  2.1   4.7
#               2001 5807      A.C. Green  PF  37  MIA  82   1  17.2  1.8   4.0
# A.J. Bramlett 2000 5161   A.J. Bramlett   C  23  CLE   8   0   7.6  0.5   2.6
# A.J. English  1991 604     A.J. English  SG  23  WSB  70  12  20.6  3.6   8.2
#               1992 1074    A.J. English  SG  24  WSB  81   6  20.6  4.5  10.4
# A.J. Green    2023 19592     A.J. Green  SG  23  MIL  35   1   9.9  1.5   3.6
# A.J. Guyton   2001 5810     A.J. Guyton  PG  22  CHI  33   8  19.1  2.4   5.8
#               2002 6363     A.J. Guyton  PG  23  CHI  45   6  13.5  2.0   5.4
#               2003 6870     A.J. Guyton  PG  24  GSW   2   0   4.5  0.0   2.0
# A.J. Hammons  2017 15291   A.J. Hammons   C  24  DAL  22   0   7.4  0.8   1.9
#
#                            FG%  ...  ORB  DRB  TRB  AST  STL  BLK  TOV   PF  \
# Player        Year              ...
# A.C. Green    1990 146    .478  ...  3.2  5.5  8.7  1.1  0.8  0.6  1.4  2.5
#               1991 641    .476  ...  2.5  3.8  6.3  0.9  0.7  0.3  1.2  1.4
#               1992 1110   .476  ...  3.7  5.6  9.3  1.4  1.1  0.4  1.4  1.7
#               1993 1569   .537  ...  3.5  5.2  8.7  1.4  1.1  0.5  1.4  1.8
#               1994 2056   .502  ...  3.4  5.8  9.2  1.7  0.9  0.5  1.2  1.7
#               1995 2544   .504  ...  2.4  5.8  8.2  1.5  0.7  0.4  1.4  1.8
#               1996 3040   .484  ...  2.0  4.7  6.8  0.9  0.5  0.3  1.0  1.7
#               1997 3615   .483  ...  2.7  5.2  7.9  0.8  0.8  0.2  0.9  1.7
#               1998 4202   .453  ...  2.7  5.5  8.1  1.5  1.0  0.3  0.8  1.9
#               1999 4760   .422  ...  1.6  2.9  4.6  0.5  0.6  0.2  0.4  1.4
#               2000 5288   .447  ...  2.0  4.0  5.9  1.0  0.6  0.2  0.6  1.5
#               2001 5807   .444  ...  1.3  2.5  3.8  0.5  0.4  0.1  0.5  1.5
# A.J. Bramlett 2000 5161   .190  ...  1.5  1.3  2.8  0.0  0.1  0.0  0.4  1.6
# A.J. English  1991 604    .439  ...  0.9  1.2  2.1  2.5  0.4  0.2  1.6  1.8
#               1992 1074   .433  ...  0.9  1.2  2.1  1.8  0.4  0.1  1.1  2.0
# A.J. Green    2023 19592  .424  ...  0.2  1.1  1.3  0.6  0.2  0.0  0.3  0.9
# A.J. Guyton   2001 5810   .406  ...  0.3  0.8  1.1  1.9  0.3  0.2  0.7  1.1
#               2002 6363   .361  ...  0.3  0.7  1.0  1.8  0.2  0.2  0.8  0.5
#               2003 6870   .000  ...  0.0  0.0  0.0  1.0  0.5  0.0  0.5  0.0
# A.J. Hammons  2017 15291  .405  ...  0.4  1.3  1.6  0.2  0.0  0.6  0.5  1.0
#
#                            PTS  Year
# Player        Year
# A.C. Green    1990 146    12.9  1990
#               1991 641     9.1  1991
#               1992 1110   13.6  1992
#               1993 1569   12.8  1993
#               1994 2056   14.7  1994
#               1995 2544   11.2  1995
#               1996 3040    7.5  1996
#               1997 3615    7.2  1997
#               1998 4202    7.3  1998
#               1999 4760    4.9  1999
#               2000 5288    5.0  2000
#               2001 5807    4.5  2001
# A.J. Bramlett 2000 5161    1.0  2000
# A.J. English  1991 604     8.8  1991
#               1992 1074   10.9  1992
# A.J. Green    2023 19592   4.4  2023
# A.J. Guyton   2001 5810    6.0  2001
#               2002 6363    5.4  2002
#               2003 6870    0.0  2003
# A.J. Hammons  2017 15291   2.2  2017
#
# [20 rows x 30 columns]

# %%
players.index = players.index.droplevel()

# %%
players.index = players.index.droplevel()

# %%
players
# Out:
#               Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  \
# 146       A.C. Green  PF  26  LAL  82  82  33.0  4.7   9.8  .478  ...  3.2
# 641       A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  2.5
# 1110      A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  3.7
# 1569      A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  3.5
# 2056      A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  3.4
# ...              ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...  ...
# 6572  Željko Rebrača   C  29  DET  74   4  15.9  2.6   5.1  .505  ...  1.1
# 7072  Željko Rebrača   C  30  DET  30  12  16.3  2.7   4.8  .552  ...  0.9
# 7653  Željko Rebrača   C  31  ATL  24   2  11.4  1.4   3.2  .442  ...  1.0
# 8253  Željko Rebrača   C  32  LAC  58   2  16.0  2.3   4.0  .568  ...  0.8
# 8847  Željko Rebrača   C  33  LAC  29   2  14.2  1.8   3.3  .542  ...  0.4
#
#       DRB  TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 146   5.5  8.7  1.1  0.8  0.6  1.4  2.5  12.9  1990
# 641   3.8  6.3  0.9  0.7  0.3  1.2  1.4   9.1  1991
# 1110  5.6  9.3  1.4  1.1  0.4  1.4  1.7  13.6  1992
# 1569  5.2  8.7  1.4  1.1  0.5  1.4  1.8  12.8  1993
# 2056  5.8  9.2  1.7  0.9  0.5  1.2  1.7  14.7  1994
# ...   ...  ...  ...  ...  ...  ...  ...   ...   ...
# 6572  2.8  3.9  0.5  0.4  1.0  1.1  2.6   6.9  2002
# 7072  2.2  3.1  0.3  0.2  0.6  1.0  2.6   6.6  2003
# 7653  1.5  2.4  0.3  0.2  0.5  0.7  2.2   3.8  2004
# 8253  2.3  3.2  0.4  0.2  0.7  0.8  2.2   5.8  2005
# 8847  1.8  2.2  0.3  0.2  0.7  0.8  2.0   4.7  2006
#
# [15615 rows x 30 columns]

# %%
players[players["Player"] == "Greg Anderson"]
# Out:
#              Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  \
# 7     Greg Anderson  PF  25  MIL  60  28  21.5  3.7   7.2  .507  ...  1.9
# 485   Greg Anderson  PF  26  DEN  68   2  13.6  1.7   4.0  .430  ...  1.4
# 944   Greg Anderson  PF  27  DEN  82  82  34.1  4.7  10.4  .456  ...  4.1
# 1889  Greg Anderson  PF  29  DET  77  47  21.1  2.6   4.8  .543  ...  2.4
# 2388  Greg Anderson  PF  30  ATL  51   0  12.2  1.1   2.0  .548  ...  1.2
# 2858  Greg Anderson  PF  31  SAS  46   7   7.5  0.5   1.0  .511  ...  0.6
# 3425  Greg Anderson   C  32  SAS  82  48  20.2  1.6   3.2  .496  ...  1.9
# 4018  Greg Anderson   C  33  ATL  50   0   8.0  0.7   1.6  .444  ...  0.8
#
#       DRB   TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 7     4.4   6.2  0.4  0.5  0.9  1.3  2.9   8.8  1990
# 485   3.3   4.7  0.2  0.5  0.7  1.2  2.1   4.3  1991
# 944   7.4  11.5  1.0  1.1  0.8  2.5  3.2  11.5  1992
# 1889  5.0   7.4  0.7  0.7  0.9  1.2  3.0   6.4  1994
# 2388  2.5   3.7  0.3  0.5  0.6  0.6  2.0   2.9  1995
# 2858  1.5   2.2  0.2  0.2  0.5  0.5  1.4   1.2  1996
# 3425  3.5   5.5  0.4  0.8  0.8  0.9  2.7   3.9  1997
# 4018  1.6   2.4  0.3  0.4  0.2  0.3  1.7   1.8  1998
#
# [8 rows x 30 columns]

# %%
combined = players.merge(mvps, how="outer", on=["Player","Year"])

# %%
combined.head(5)
# Out:
#        Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  AST  STL  BLK  \
# 0  A.C. Green  PF  26  LAL  82  82  33.0  4.7   9.8  .478  ...  1.1  0.8  0.6
# 1  A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.9  0.7  0.3
# 2  A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.4  1.1  0.4
# 3  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.4  1.1  0.5
# 4  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  1.7  0.9  0.5
#
#    TOV   PF   PTS  Year Pts Won Pts Max Share
# 0  1.4  2.5  12.9  1990     NaN     NaN   NaN
# 1  1.2  1.4   9.1  1991     NaN     NaN   NaN
# 2  1.4  1.7  13.6  1992     NaN     NaN   NaN
# 3  1.4  1.8  12.8  1993     NaN     NaN   NaN
# 4  1.2  1.7  14.7  1994     NaN     NaN   NaN
#
# [5 rows x 33 columns]

# %%
combined[combined["Pts Won"] > 0]
# Out:
#               Player    Pos Age   Tm   G  GS    MP    FG   FGA   FG%  ...  \
# 210     Al Jefferson      C  29  CHA  73  73  35.0   9.6  18.8  .509  ...
# 366    Allen Iverson     PG  21  PHI  76  74  40.1   8.2  19.8  .416  ...
# 368    Allen Iverson     SG  23  PHI  48  48  41.5   9.1  22.0  .412  ...
# 369    Allen Iverson     SG  24  PHI  70  70  40.8  10.4  24.8  .421  ...
# 370    Allen Iverson     SG  25  PHI  71  71  42.0  10.7  25.5  .420  ...
# ...              ...    ...  ..  ...  ..  ..   ...   ...   ...   ...  ...
# 15053   Vince Carter     SF  23  TOR  82  82  38.1   9.6  20.7  .465  ...
# 15054   Vince Carter     SF  24  TOR  75  75  39.7  10.2  22.1  .460  ...
# 15058   Vince Carter  SF-SG  28  NJN  77  76  36.7   9.0  20.0  .452  ...
# 15459       Yao Ming      C  23  HOU  82  82  32.8   6.5  12.5  .522  ...
# 15464       Yao Ming      C  28  HOU  77  77  33.6   7.4  13.4  .548  ...
#
#        AST  STL  BLK  TOV   PF   PTS  Year Pts Won Pts Max  Share
# 210    2.1  0.9  1.1  1.7  2.4  21.8  2014    34.0  1250.0  0.027
# 366    7.5  2.1  0.3  4.4  3.1  23.5  1997     1.0  1150.0  0.001
# 368    4.6  2.3  0.1  3.5  2.0  26.8  1999   319.0  1180.0  0.270
# 369    4.7  2.1  0.1  3.3  2.3  28.4  2000   132.0  1210.0  0.109
# 370    4.6  2.5  0.3  3.3  2.1  31.1  2001  1121.0  1240.0  0.904
# ...    ...  ...  ...  ...  ...   ...   ...     ...     ...    ...
# 15053  3.9  1.3  1.1  2.2  3.2  25.7  2000    51.0  1210.0  0.042
# 15054  3.9  1.5  1.1  2.2  2.7  27.6  2001     7.0  1240.0  0.006
# 15058  4.2  1.4  0.6  2.2  3.2  24.5  2005     3.0  1270.0  0.002
# 15459  1.5  0.3  1.9  2.5  3.3  17.5  2004     1.0  1230.0  0.001
# 15464  1.8  0.4  1.9  3.0  3.3  19.7  2009     1.0  1210.0  0.001
#
# [513 rows x 33 columns]

# %%
combined[["Pts Won", "Pts Max", "Share"]] = combined[["Pts Won", "Pts Max", "Share"]].fillna(0)

# %%
combined
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  AST  \
# 0          A.C. Green  PF  26  LAL  82  82  33.0  4.7   9.8  .478  ...  1.1
# 1          A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.9
# 2          A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.4
# 3          A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.4
# 4          A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  1.7
# ...               ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...  ...
# 15610  Željko Rebrača   C  29  DET  74   4  15.9  2.6   5.1  .505  ...  0.5
# 15611  Željko Rebrača   C  30  DET  30  12  16.3  2.7   4.8  .552  ...  0.3
# 15612  Željko Rebrača   C  31  ATL  24   2  11.4  1.4   3.2  .442  ...  0.3
# 15613  Željko Rebrača   C  32  LAC  58   2  16.0  2.3   4.0  .568  ...  0.4
# 15614  Željko Rebrača   C  33  LAC  29   2  14.2  1.8   3.3  .542  ...  0.3
#
#        STL  BLK  TOV   PF   PTS  Year Pts Won Pts Max Share
# 0      0.8  0.6  1.4  2.5  12.9  1990     0.0     0.0   0.0
# 1      0.7  0.3  1.2  1.4   9.1  1991     0.0     0.0   0.0
# 2      1.1  0.4  1.4  1.7  13.6  1992     0.0     0.0   0.0
# 3      1.1  0.5  1.4  1.8  12.8  1993     0.0     0.0   0.0
# 4      0.9  0.5  1.2  1.7  14.7  1994     0.0     0.0   0.0
# ...    ...  ...  ...  ...   ...   ...     ...     ...   ...
# 15610  0.4  1.0  1.1  2.6   6.9  2002     0.0     0.0   0.0
# 15611  0.2  0.6  1.0  2.6   6.6  2003     0.0     0.0   0.0
# 15612  0.2  0.5  0.7  2.2   3.8  2004     0.0     0.0   0.0
# 15613  0.2  0.7  0.8  2.2   5.8  2005     0.0     0.0   0.0
# 15614  0.2  0.7  0.8  2.0   4.7  2006     0.0     0.0   0.0
#
# [15615 rows x 33 columns]

# %%
teams = pd.read_csv("teams.csv")

# %%
teams
# Out:
#       Unnamed: 0   W   L  W/L%    GB   PS/G   PA/G    SRS  Year  \
# 0              0  53  29  .646     —  110.2  105.2   4.23  1990
# 1              1  52  30  .634   1.0  110.0  106.0   3.23  1990
# 2              2  45  37  .549   8.0  108.3  106.9   0.78  1990
# 3              3  31  51  .378  22.0  107.7  109.9  -2.43  1990
# 4              4  18  64  .220  35.0  100.6  110.3  -9.59  1990
# ...          ...  ..  ..   ...   ...    ...    ...    ...   ...
# 1128          13  51  31  .622     —  116.9  113.0   3.60  2023
# 1129          14  42  40  .512   9.0  114.4  112.5   1.63  2023
# 1130          15  38  44  .463  13.0  114.2  114.1  -0.14  2023
# 1131          16  22  60  .268  29.0  110.7  118.6  -7.62  2023
# 1132          17  22  60  .268  29.0  113.0  123.1  -9.82  2023
#
#                        Team
# 0       Philadelphia 76ers*
# 1           Boston Celtics*
# 2          New York Knicks*
# 3        Washington Bullets
# 4                Miami Heat
# ...                     ...
# 1128     Memphis Grizzlies*
# 1129  New Orleans Pelicans*
# 1130       Dallas Mavericks
# 1131        Houston Rockets
# 1132      San Antonio Spurs
#
# [1133 rows x 10 columns]

# %%
teams.head(30)
# Out:
#     Unnamed: 0                 W                 L              W/L%  \
# 0            0                53                29              .646
# 1            1                52                30              .634
# 2            2                45                37              .549
# 3            3                31                51              .378
# 4            4                18                64              .220
# 5            5                17                65              .207
# 6            6  Central Division  Central Division  Central Division
# 7            7                59                23              .720
# 8            8                55                27              .671
# 9            9                44                38              .537
# 10          10                42                40              .512
# 11          11                42                40              .512
# 12          12                41                41              .500
# 13          13                18                64              .220
# 14           0  Midwest Division  Midwest Division  Midwest Division
# 15           1                56                26              .683
# 16           2                55                27              .671
# 17           3                47                35              .573
# 18           4                43                39              .524
# 19           5                41                41              .500
# 20           6                22                60              .268
# 21           7                19                63              .232
# 22           8  Pacific Division  Pacific Division  Pacific Division
# 23           9                63                19              .768
# 24          10                59                23              .720
# 25          11                54                28              .659
# 26          12                41                41              .500
# 27          13                37                45              .451
# 28          14                30                52              .366
# 29          15                23                59              .280
#
#                   GB              PS/G              PA/G               SRS  \
# 0                  —             110.2             105.2              4.23
# 1                1.0             110.0             106.0              3.23
# 2                8.0             108.3             106.9              0.78
# 3               22.0             107.7             109.9             -2.43
# 4               35.0             100.6             110.3             -9.59
# 5               36.0             100.1             108.0             -7.82
# 6   Central Division  Central Division  Central Division  Central Division
# 7                  —             104.3              98.3              5.41
# 8                4.0             109.5             106.2              2.74
# 9               15.0             106.0             106.8             -1.06
# 10              17.0             102.6             102.9             -0.62
# 11              17.0             109.3             109.1             -0.18
# 12              18.0             108.5             107.5              0.64
# 13              41.0             110.9             119.8             -8.73
# 14  Midwest Division  Midwest Division  Midwest Division  Midwest Division
# 15                 —             106.3             102.8              3.58
# 16               1.0             106.8             102.0              4.82
# 17               9.0             102.2             102.2              0.42
# 18              13.0             114.6             113.2              1.56
# 19              15.0             106.7             105.3              1.71
# 20              34.0              95.2              99.4             -3.60
# 21              37.0             100.4             108.2             -7.00
# 22  Pacific Division  Pacific Division  Pacific Division  Pacific Division
# 23                 —             110.7             103.9              6.74
# 24               4.0             114.2             107.9              6.48
# 25               9.0             114.9             107.8              7.09
# 26              22.0             106.9             105.9              1.40
# 27              26.0             116.3             119.4             -2.55
# 28              33.0             103.8             107.2             -2.80
# 29              40.0             101.7             106.8             -4.41
#
#     Year                     Team
# 0   1990      Philadelphia 76ers*
# 1   1990          Boston Celtics*
# 2   1990         New York Knicks*
# 3   1990       Washington Bullets
# 4   1990               Miami Heat
# 5   1990          New Jersey Nets
# 6   1990         Central Division
# 7   1990         Detroit Pistons*
# 8   1990           Chicago Bulls*
# 9   1990         Milwaukee Bucks*
# 10  1990     Cleveland Cavaliers*
# 11  1990          Indiana Pacers*
# 12  1990            Atlanta Hawks
# 13  1990            Orlando Magic
# 14  1990         Midwest Division
# 15  1990       San Antonio Spurs*
# 16  1990               Utah Jazz*
# 17  1990        Dallas Mavericks*
# 18  1990          Denver Nuggets*
# 19  1990         Houston Rockets*
# 20  1990   Minnesota Timberwolves
# 21  1990        Charlotte Hornets
# 22  1990         Pacific Division
# 23  1990      Los Angeles Lakers*
# 24  1990  Portland Trail Blazers*
# 25  1990            Phoenix Suns*
# 26  1990      Seattle SuperSonics
# 27  1990    Golden State Warriors
# 28  1990     Los Angeles Clippers
# 29  1990         Sacramento Kings

# %%
teams = teams[~teams["W"].str.contains("Division")]

# %%
teams
# Out:
#       Unnamed: 0   W   L  W/L%    GB   PS/G   PA/G    SRS  Year  \
# 0              0  53  29  .646     —  110.2  105.2   4.23  1990
# 1              1  52  30  .634   1.0  110.0  106.0   3.23  1990
# 2              2  45  37  .549   8.0  108.3  106.9   0.78  1990
# 3              3  31  51  .378  22.0  107.7  109.9  -2.43  1990
# 4              4  18  64  .220  35.0  100.6  110.3  -9.59  1990
# ...          ...  ..  ..   ...   ...    ...    ...    ...   ...
# 1128          13  51  31  .622     —  116.9  113.0   3.60  2023
# 1129          14  42  40  .512   9.0  114.4  112.5   1.63  2023
# 1130          15  38  44  .463  13.0  114.2  114.1  -0.14  2023
# 1131          16  22  60  .268  29.0  110.7  118.6  -7.62  2023
# 1132          17  22  60  .268  29.0  113.0  123.1  -9.82  2023
#
#                        Team
# 0       Philadelphia 76ers*
# 1           Boston Celtics*
# 2          New York Knicks*
# 3        Washington Bullets
# 4                Miami Heat
# ...                     ...
# 1128     Memphis Grizzlies*
# 1129  New Orleans Pelicans*
# 1130       Dallas Mavericks
# 1131        Houston Rockets
# 1132      San Antonio Spurs
#
# [993 rows x 10 columns]

# %%
teams["Team"] = teams["Team"].str.replace("*","", regex = False)
# Out:
# C:\Users\ScottieDFloppyPC\AppData\Local\Temp\ipykernel_7396\2800672333.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teams["Team"] = teams["Team"].str.replace("*","", regex = False)

# %%
teams
# Out:
#       Unnamed: 0   W   L  W/L%    GB   PS/G   PA/G    SRS  Year  \
# 0              0  53  29  .646     —  110.2  105.2   4.23  1990
# 1              1  52  30  .634   1.0  110.0  106.0   3.23  1990
# 2              2  45  37  .549   8.0  108.3  106.9   0.78  1990
# 3              3  31  51  .378  22.0  107.7  109.9  -2.43  1990
# 4              4  18  64  .220  35.0  100.6  110.3  -9.59  1990
# ...          ...  ..  ..   ...   ...    ...    ...    ...   ...
# 1128          13  51  31  .622     —  116.9  113.0   3.60  2023
# 1129          14  42  40  .512   9.0  114.4  112.5   1.63  2023
# 1130          15  38  44  .463  13.0  114.2  114.1  -0.14  2023
# 1131          16  22  60  .268  29.0  110.7  118.6  -7.62  2023
# 1132          17  22  60  .268  29.0  113.0  123.1  -9.82  2023
#
#                       Team
# 0       Philadelphia 76ers
# 1           Boston Celtics
# 2          New York Knicks
# 3       Washington Bullets
# 4               Miami Heat
# ...                    ...
# 1128     Memphis Grizzlies
# 1129  New Orleans Pelicans
# 1130      Dallas Mavericks
# 1131       Houston Rockets
# 1132     San Antonio Spurs
#
# [993 rows x 10 columns]

# %%
teams["Team"].unique()
# Out:
# array(['Philadelphia 76ers', 'Boston Celtics', 'New York Knicks',
#        'Washington Bullets', 'Miami Heat', 'New Jersey Nets',
#        'Detroit Pistons', 'Chicago Bulls', 'Milwaukee Bucks',
#        'Cleveland Cavaliers', 'Indiana Pacers', 'Atlanta Hawks',
#        'Orlando Magic', 'San Antonio Spurs', 'Utah Jazz',
#        'Dallas Mavericks', 'Denver Nuggets', 'Houston Rockets',
#        'Minnesota Timberwolves', 'Charlotte Hornets',
#        'Los Angeles Lakers', 'Portland Trail Blazers', 'Phoenix Suns',
#        'Seattle SuperSonics', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Sacramento Kings', 'Toronto Raptors',
#        'Vancouver Grizzlies', 'Washington Wizards', 'Memphis Grizzlies',
#        'New Orleans Hornets', 'Charlotte Bobcats',
#        'New Orleans/Oklahoma City Hornets', 'Oklahoma City Thunder',
#        'Brooklyn Nets', 'New Orleans Pelicans'], dtype=object)

# %%
combined["Tm"].unique()
# Out:
# array(['LAL', 'PHO', 'DAL', 'MIA', 'CLE', 'WSB', 'MIL', 'CHI', 'GSW',
#        'IND', 'WAS', 'MIN', 'BOS', 'ATL', 'HOU', 'DEN', 'ORL', 'NOH',
#        'TOR', 'SAC', 'CHO', 'PHI', 'POR', 'DET', 'OKC', 'UTA', 'VAN',
#        'SEA', 'NJN', 'NOK', 'LAC', 'CHA', 'MEM', 'NYK', 'NOP', 'BRK',
#        'SAS', 'CHH'], dtype=object)

# %%
nicknames = {}

with open("nicknames.csv") as f:
    lines = f.readlines()
    for line in lines[1:]:
        abbrev,name = line.replace("\n","").split(",")
        nicknames[abbrev] = name

# %%
nicknames
# Out:
# {'ATL': 'Atlanta Hawks',
#  'BRK': 'Brooklyn Nets',
#  'BKN': 'Brooklyn Nets',
#  'BOS': 'Boston Celtics',
#  'CHA': 'Charlotte Bobcats',
#  'CHH': 'Charlotte Hornets',
#  'CHO': 'Charlotte Hornets',
#  'CHI': 'Chicago Bulls',
#  'CLE': 'Cleveland Cavaliers',
#  'DAL': 'Dallas Mavericks',
#  'DEN': 'Denver Nuggets',
#  'DET': 'Detroit Pistons',
#  'GSW': 'Golden State Warriors',
#  'HOU': 'Houston Rockets',
#  'IND': 'Indiana Pacers',
#  'LAC': 'Los Angeles Clippers',
#  'LAL': 'Los Angeles Lakers',
#  'MEM': 'Memphis Grizzlies',
#  'MIA': 'Miami Heat',
#  'MIL': 'Milwaukee Bucks',
#  'MIN': 'Minnesota Timberwolves',
#  'NJN': 'New Jersey Nets',
#  'NOH': 'New Orleans Hornets',
#  'NOP': 'New Orleans Pelicans',
#  'NOK': 'New Orleans/Oklahoma City Hornets',
#  'NYK': 'New York Knicks',
#  'OKC': 'Oklahoma City Thunder',
#  'ORL': 'Orlando Magic',
#  'PHI': 'Philadelphia 76ers',
#  'PHX': 'Phoenix Suns',
#  'PHO': 'Phoenix Suns',
#  'POR': 'Portland Trail Blazers',
#  'SEA': 'Seattle SuperSonics',
#  'SAC': 'Sacramento Kings',
#  'SAS': 'San Antonio Spurs',
#  'TOR': 'Toronto Raptors',
#  'UTA': 'Utah Jazz',
#  'VAN': 'Vancouver Grizzlies',
#  'WAS': 'Washington Wizards',
#  'WSB': 'Washington Bullets'}

# %%
combined["Team"] = combined["Tm"].map(nicknames)

# %%
combined.head(5)
# Out:
#        Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  STL  BLK  TOV  \
# 0  A.C. Green  PF  26  LAL  82  82  33.0  4.7   9.8  .478  ...  0.8  0.6  1.4
# 1  A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.7  0.3  1.2
# 2  A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.1  0.4  1.4
# 3  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.1  0.5  1.4
# 4  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  0.9  0.5  1.2
#
#     PF   PTS  Year Pts Won Pts Max Share                Team
# 0  2.5  12.9  1990     0.0     0.0   0.0  Los Angeles Lakers
# 1  1.4   9.1  1991     0.0     0.0   0.0  Los Angeles Lakers
# 2  1.7  13.6  1992     0.0     0.0   0.0  Los Angeles Lakers
# 3  1.8  12.8  1993     0.0     0.0   0.0  Los Angeles Lakers
# 4  1.7  14.7  1994     0.0     0.0   0.0        Phoenix Suns
#
# [5 rows x 34 columns]

# %%
stats = combined.merge(teams, how="outer", on=["Team","Year"])

# %%
stats
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ... Share  \
# 0          A.C. Green  PF  26  LAL  82  82  33.0  4.7   9.8  .478  ...   0.0
# 1         Byron Scott  SG  28  LAL  77  77  33.7  6.1  13.1  .470  ...   0.0
# 2        James Worthy  SF  28  LAL  80  80  37.0  8.9  16.2  .548  ...   0.0
# 3       Jawann Oldham   C  32  LAL   6   0   7.5  0.5   1.0  .500  ...   0.0
# 4         Jay Vincent  SF  30  LAL  41   6  11.2  2.1   4.5  .470  ...   0.0
# ...               ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...   ...
# 15610   Spencer Hawes  PF  28  MIL  54   1  14.8  2.5   5.1  .484  ...   0.0
# 15611     Steve Novak  PF  33  MIL   8   0   2.8  0.3   0.9  .286  ...   0.0
# 15612  Terrence Jones  PF  25  MIL  54  12  23.5  4.3   9.1  .470  ...   0.0
# 15613      Thon Maker   C  19  MIL  57  34   9.9  1.5   3.2  .459  ...   0.0
# 15614      Tony Snell  SG  25  MIL  80  80  29.2  3.1   6.8  .455  ...   0.0
#
#                      Team Unnamed: 0   W   L  W/L%   GB   PS/G   PA/G    SRS
# 0      Los Angeles Lakers          9  63  19  .768    —  110.7  103.9   6.74
# 1      Los Angeles Lakers          9  63  19  .768    —  110.7  103.9   6.74
# 2      Los Angeles Lakers          9  63  19  .768    —  110.7  103.9   6.74
# 3      Los Angeles Lakers          9  63  19  .768    —  110.7  103.9   6.74
# 4      Los Angeles Lakers          9  63  19  .768    —  110.7  103.9   6.74
# ...                   ...        ...  ..  ..   ...  ...    ...    ...    ...
# 15610     Milwaukee Bucks          7  42  40  .512  9.0  103.6  103.8  -0.45
# 15611     Milwaukee Bucks          7  42  40  .512  9.0  103.6  103.8  -0.45
# 15612     Milwaukee Bucks          7  42  40  .512  9.0  103.6  103.8  -0.45
# 15613     Milwaukee Bucks          7  42  40  .512  9.0  103.6  103.8  -0.45
# 15614     Milwaukee Bucks          7  42  40  .512  9.0  103.6  103.8  -0.45
#
# [15615 rows x 42 columns]

# %%
combined
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  STL  \
# 0          A.C. Green  PF  26  LAL  82  82  33.0  4.7   9.8  .478  ...  0.8
# 1          A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.7
# 2          A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.1
# 3          A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.1
# 4          A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  0.9
# ...               ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...  ...
# 15610  Željko Rebrača   C  29  DET  74   4  15.9  2.6   5.1  .505  ...  0.4
# 15611  Željko Rebrača   C  30  DET  30  12  16.3  2.7   4.8  .552  ...  0.2
# 15612  Željko Rebrača   C  31  ATL  24   2  11.4  1.4   3.2  .442  ...  0.2
# 15613  Željko Rebrača   C  32  LAC  58   2  16.0  2.3   4.0  .568  ...  0.2
# 15614  Željko Rebrača   C  33  LAC  29   2  14.2  1.8   3.3  .542  ...  0.2
#
#        BLK  TOV   PF   PTS  Year Pts Won Pts Max Share                  Team
# 0      0.6  1.4  2.5  12.9  1990     0.0     0.0   0.0    Los Angeles Lakers
# 1      0.3  1.2  1.4   9.1  1991     0.0     0.0   0.0    Los Angeles Lakers
# 2      0.4  1.4  1.7  13.6  1992     0.0     0.0   0.0    Los Angeles Lakers
# 3      0.5  1.4  1.8  12.8  1993     0.0     0.0   0.0    Los Angeles Lakers
# 4      0.5  1.2  1.7  14.7  1994     0.0     0.0   0.0          Phoenix Suns
# ...    ...  ...  ...   ...   ...     ...     ...   ...                   ...
# 15610  1.0  1.1  2.6   6.9  2002     0.0     0.0   0.0       Detroit Pistons
# 15611  0.6  1.0  2.6   6.6  2003     0.0     0.0   0.0       Detroit Pistons
# 15612  0.5  0.7  2.2   3.8  2004     0.0     0.0   0.0         Atlanta Hawks
# 15613  0.7  0.8  2.2   5.8  2005     0.0     0.0   0.0  Los Angeles Clippers
# 15614  0.7  0.8  2.0   4.7  2006     0.0     0.0   0.0  Los Angeles Clippers
#
# [15615 rows x 34 columns]

# %%
del stats["Unnamed: 0"]

# %%
stats = stats.apply(pd.to_numeric, errors="ignore")

# %%
stats.dtypes
# Out:
# Player      object
# Pos         object
# Age          int64
# Tm          object
# G            int64
# GS           int64
# MP         float64
# FG         float64
# FGA        float64
# FG%        float64
# 3P         float64
# 3PA        float64
# 3P%        float64
# 2P         float64
# 2PA        float64
# 2P%        float64
# eFG%       float64
# FT         float64
# FTA        float64
# FT%        float64
# ORB        float64
# DRB        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# TOV        float64
# PF         float64
# PTS        float64
# Year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Team        object
# W            int64
# L            int64
# W/L%       float64
# GB          object
# PS/G       float64
# PA/G       float64
# SRS        float64
# dtype: object

# %%
stats["GB"].unique()
# Out:
# array(['—', '5.0', '14.0', '23.0', '7.0', '40.0', '42.0', '18.0', '6.0',
#        '24.0', '26.0', '37.0', '29.0', '21.0', '28.0', '13.0', '25.0',
#        '8.0', '19.0', '3.0', '1.0', '17.0', '15.0', '9.0', '2.0', '35.0',
#        '20.0', '11.0', '16.0', '41.0', '12.0', '50.0', '10.0', '30.0',
#        '34.0', '4.0', '1.5', '22.0', '51.0', '36.0', '43.0', '39.0',
#        '18.5', '31.0', '48.0', '46.0', '10.5', '32.0', '38.0', '27.0',
#        '33.0', '21.5', '45.0', '22.5', '25.5', '3.5', '20.5', '11.5',
#        '44.0', '52.0', '56.0', '2.5', '12.5', '47.0', '32.5', '4.5'],
#       dtype=object)

# %%
stats["GB"] = stats["GB"].str.replace("—","0")

# %%
stats["GB"].unique()
# Out:
# array(['0', '5.0', '14.0', '23.0', '7.0', '40.0', '42.0', '18.0', '6.0',
#        '24.0', '26.0', '37.0', '29.0', '21.0', '28.0', '13.0', '25.0',
#        '8.0', '19.0', '3.0', '1.0', '17.0', '15.0', '9.0', '2.0', '35.0',
#        '20.0', '11.0', '16.0', '41.0', '12.0', '50.0', '10.0', '30.0',
#        '34.0', '4.0', '1.5', '22.0', '51.0', '36.0', '43.0', '39.0',
#        '18.5', '31.0', '48.0', '46.0', '10.5', '32.0', '38.0', '27.0',
#        '33.0', '21.5', '45.0', '22.5', '25.5', '3.5', '20.5', '11.5',
#        '44.0', '52.0', '56.0', '2.5', '12.5', '47.0', '32.5', '4.5'],
#       dtype=object)

# %%
stats["GB"] = pd.to_numeric(stats["GB"])

# %%
stats.dtypes
# Out:
# Player      object
# Pos         object
# Age          int64
# Tm          object
# G            int64
# GS           int64
# MP         float64
# FG         float64
# FGA        float64
# FG%        float64
# 3P         float64
# 3PA        float64
# 3P%        float64
# 2P         float64
# 2PA        float64
# 2P%        float64
# eFG%       float64
# FT         float64
# FTA        float64
# FT%        float64
# ORB        float64
# DRB        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# TOV        float64
# PF         float64
# PTS        float64
# Year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Team        object
# W            int64
# L            int64
# W/L%       float64
# GB         float64
# PS/G       float64
# PA/G       float64
# SRS        float64
# dtype: object

# %%
stats.to_csv("player_mvp_stats.csv")

# %%
highest_scoring = stats[stats["G"] > 70].sort_values("PTS", ascending=False).head(10)

# %%
highest_scoring
# Out:
#                   Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  ...  \
# 10613       James Harden  PG   29  HOU  78  78  36.8  10.8  24.5  0.442  ...
# 1200         Kobe Bryant  SG   27  LAL  80  80  41.0  12.2  27.2  0.450  ...
# 10922     Michael Jordan  SG   26  CHI  82  82  39.0  12.6  24.0  0.526  ...
# 4960       Allen Iverson  PG   30  PHI  72  72  43.1  11.3  25.3  0.447  ...
# 10959     Michael Jordan  SG   29  CHI  78  78  39.3  12.7  25.7  0.495  ...
# 7590       Tracy McGrady  SG   23  ORL  75  74  39.4  11.1  24.2  0.457  ...
# 7002        Kevin Durant  SF   25  OKC  81  81  38.5  10.5  20.8  0.503  ...
# 1214         Kobe Bryant  SG   28  LAL  77  77  40.8  10.6  22.8  0.463  ...
# 7054   Russell Westbrook  PG   28  OKC  81  81  34.6  10.2  24.0  0.425  ...
# 10933     Michael Jordan  SG   27  CHI  82  82  37.0  12.1  22.4  0.539  ...
#
#        Pts Max  Share                   Team   W   L   W/L%    GB   PS/G  \
# 10613   1010.0  0.768        Houston Rockets  53  29  0.646   0.0  113.9
# 1200    1250.0  0.386     Los Angeles Lakers  45  37  0.549   9.0   99.4
# 10922    920.0  0.613          Chicago Bulls  55  27  0.671   4.0  109.5
# 4960    1250.0  0.001     Philadelphia 76ers  38  44  0.463  11.0   99.4
# 10959    980.0  0.577          Chicago Bulls  57  25  0.695   0.0  105.2
# 7590    1190.0  0.359          Orlando Magic  42  40  0.512   7.0   98.5
# 7002    1250.0  0.986  Oklahoma City Thunder  59  23  0.720   0.0  106.2
# 1214    1290.0  0.404     Los Angeles Lakers  42  40  0.512  19.0  103.3
# 7054    1010.0  0.879  Oklahoma City Thunder  47  35  0.573   4.0  106.6
# 10933    960.0  0.928          Chicago Bulls  61  21  0.744   0.0  110.0
#
#         PA/G   SRS
# 10613  109.1  4.96
# 1200    96.9  2.53
# 10922  106.2  2.74
# 4960   101.3 -2.10
# 10959   98.9  6.19
# 7590    98.4 -0.39
# 7002    99.8  6.66
# 1214   103.4  0.24
# 7054   105.8  1.14
# 10933  101.0  8.57
#
# [10 rows x 41 columns]

# %%
highest_scoring.plot.bar("Player", "PTS")
# Out:
# <Axes: xlabel='Player'>

# %%
highest_scoring = stats.groupby("Year").apply(lambda x: x.sort_values("PTS", ascending = False).head(1))

# %%
highest_scoring.plot.bar("Year","PTS")
# Out:
# <Axes: xlabel='Year'>

# %%
stats.corr(numeric_only = True)["Share"]
# Out:
# Age        0.018729
# G          0.088696
# GS         0.166820
# MP         0.160503
# FG         0.273981
# FGA        0.245617
# FG%        0.066498
# 3P         0.088872
# 3PA        0.089536
# 3P%        0.014185
# 2P         0.276201
# 2PA        0.250828
# 2P%        0.060947
# eFG%       0.058399
# FT         0.320685
# FTA        0.325725
# FT%        0.037579
# ORB        0.105819
# DRB        0.219363
# TRB        0.192626
# AST        0.199385
# STL        0.173613
# BLK        0.153786
# TOV        0.234351
# PF         0.075438
# PTS        0.286414
# Year      -0.009783
# Pts Won    0.994437
# Pts Max    0.523091
# Share      1.000000
# W          0.120812
# L         -0.120190
# W/L%       0.124428
# GB        -0.099900
# PS/G       0.038729
# PA/G      -0.037555
# SRS        0.118978
# Name: Share, dtype: float64

# %%
stats.corr(numeric_only = True)["Share"].plot.bar()
# Out:
# <Axes: >
